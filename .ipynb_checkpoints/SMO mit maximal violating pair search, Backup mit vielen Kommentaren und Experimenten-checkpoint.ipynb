# %%
import numpy as np

# %%
#random test problem

d = 10
l = 100
data1x = np.random.randint(255, size=(d-1,l))
data1y = np.random.randint(255, size=(1,l))
data2x = np.random.randint(255, size =(d-1,l))
data2y = -np.random.randint(-20,255, size=(1,l))
data1 = np.concatenate((data1x,data1y))
data2 = np.concatenate((data2x,data2y))
data = np.concatenate((data1,data2), axis = 1)
data = np.transpose(data)

label1 = np.ones(l).astype(int)
label2 = - label1;
label = np.concatenate((label1,label2))

#print(label)

# %% [markdown]
# ### Maximal violating pair SMO

# %%
def F(i,alpha):
    
    out = - label[i]
    for j in range(l):
        out += alpha[j]*label[j]*kernel(data[i],data[j])
    return out

# %%
def I_membership_no(a,y,C):
    if 0 < a < C:
        return 0
    elif a == 0 and y == 1:
        return 1
    elif a == C and y == -1:
        return 2
    elif a == C and y == 1:
        return 3
    else:
        return 4

# %%
def smo_original(data,label,C,kernel,tol,violationcheckyesorno):
    
    #bisher unnoetig
    #eps = 1e-12
    
    l = label.shape[0]
    alpha = np.zeros(l)
    
    fcache = -label.astype(float)
    
    b_up = [-1]
    b_low = [1]
    
    I = np.zeros((5,l), dtype=np.int)
    I[1,:] = (label == 1).astype(int)
    I[4,:] = (label == -1).astype(int)

    i_up = [min(np.nonzero(I[1,:])[0])]
    i_low = [min(np.nonzero(I[4,:])[0])]
    
    
    ##############################################################################################
    # auxiliary functions for takeStep and examineExample
    
    def I_membership(a,y):
        if 0 < a and a < C:
            return np.array([1,0,0,0,0])
        elif a == 0 and y == 1:
            return np.array([0,1,0,0,0])
        elif a == C and y == -1:
            return np.array([0,0,1,0,0])
        elif a == C and y == 1:
            return np.array([0,0,0,1,0])
        else:
            return np.array([0,0,0,0,1])
    

    def I_membership_no(a,y):
        if 0 < a < C:
            return 0
        elif a == 0 and y == 1:
            return 1
        elif a == C and y == -1:
            return 2
        elif a == C and y == 1:
            return 3
        else:
            return 4
        
    def F(i,alpha):
        
        #avoid for loop in case of standard scalar product kernel
        if kernel_identifier == 'standard scalar product':
            k = alpha * label;
            m = np.dot(data[:,i],data)
            out = -label[i] + np.dot(k,m)
        else: 
            out = - label[i]
            for j in range(l):
                out += alpha[j]*label[j]*kernel(data[:,i],data[:,j])
        return out
    
    
    ##############################################################################################   
    
    
    
    
    ##############################################################################################
    # subprocedure takeStep
    
    def takeStep(i1,i2):

    
        if i1 == i2: 
            return 0
        alph1 = alpha[i1]
        alph2 = alpha[i2]
        y1 = label[i1]
        y2 = label[i2]  
   
        F1 = fcache[i1]
        F2 = fcache[i2]
        s = y1*y2
    
        if s == -1:
            L = max(0,alph2-alph1)
            H = min(C,C+alph2-alph1)
        else:
            L = max(0,alph2+alph1-C)
            H = min(C,alph2+alph1)
    
        if L == H: return 0
    
        k11 = kernel(data[:,i1],data[:,i1])
        k12 = kernel(data[:,i1],data[:,i2])
        k22 = kernel(data[:,i2],data[:,i2])
    
        eta = 2*k12 - k11 - k22
        if eta < 0:
            a2 = alph2 - y2*(F1-F2)/eta
            if a2 < L:
                a2 = L
            elif a2 > H:
                a2 = H
        else:
            #print('Error: eta == 0')
            raise ValueError('Error: eta == 0')
    
        #if abs(a2-alph2) < eps*(a2+alph2+eps):
            #return 0
    
        a1 = alph1 + s*(alph2-a2)
    
   
        # update alpha
        alpha[i1] = a1
        alpha[i2] = a2
    
        # update I
        I[:,i1] =  I_membership(a1,y1)
        I[:,i2] =  I_membership(a2,y2)
    
        # update fcache[i] here for i in I_0: a[0:3][:,4:9]
        ind_0 = (np.nonzero(I[0,:]))[0]
        
        #avoid for loop in case of standard scalar product kernel
        if kernel_identifier == 'standard scalar product':
            fcache[ind_0] += y1*(a1-alph1)*np.dot(data[:,i1],data[:,ind_0]) + y2*(a2-alph2)*np.dot(data[:,i2],data[:,ind_0])
        else:
            for i in ind_0:
                fcache[i] = fcache[i] + y1*(a1-alph1)*kernel(data[:,i],data[:,i1]) + y2*(a2-alph2)*kernel(data[:,i],data[:,i2])
    
        # update fcache for indices i1 and i2
        fcache[i1] = F1 + y1*(a1-alph1)*k11 + y2*(a2-alph2)*k12
        fcache[i2] = F2 + y1*(a1-alph1)*k12 + y2*(a2-alph2)*k22
        
        
        b_low[0] = -float('inf')
        b_up[0] = - b_low[0]
        
        if np.size(ind_0) > 0:
            for i in ind_0:
                if fcache[i] > b_low[0]:
                    b_low[0] = fcache[i]
                    i_low[0] = i
                if fcache[i] < b_up:
                    b_up[0] = fcache[i]
                    i_up[0] = i
       
        memb1 = I_membership_no(a1,y1)
        memb2 = I_membership_no(a2,y2)
        if memb1 in (1,2) and fcache[i1] < b_up[0]:
            b_up[0] = fcache[i1]
            i_up[0] = i1
        if memb1 in (3,4) and fcache[i1] > b_low[0]:
            b_low[0] = fcache[i1]
            i_low[0] = i1
        if memb2 in (1,2) and fcache[i2] < b_up[0]:
            b_up[0] = fcache[i2]
            i_up[0] = i2
        if memb2 in (3,4) and fcache[i2] > b_low[0]:
            b_low[0] = fcache[i2]
            i_low[0] = i2

        return 1
    
    ##############################################################################################
    
    
    
    
    ##############################################################################################
    #subprocedure examineExample
    
    def examineExample(i2):

    
        y2 = label[i2]
        alph2 = alpha[i2]
        memb_i2 = I_membership_no(alph2,y2);
    
        # look up or compute F2:= F_i2
        if memb_i2 == 0:
            F2 = fcache[i2]
        else:
            fcache[i2] = F(i2,alpha)
            F2 = fcache[i2]
        
            # in case i2 not in I_0, see if F2 changes or estimate of b_low or b_up
            if memb_i2 in (1,2) and F2 < b_up[0]:
                b_up[0] = F2
                i_up[0] = i2
            elif memb_i2 in (3,4) and F2 > b_low[0]:
                b_low[0] = F2
                i_low[0] = i2
    
        optimality = 1
        if memb_i2 in (0,1,2):
            if b_low[0] - F2 > tol:
                optimality = 0
                i1 = i_low[0]
        if memb_i2 in (0,3,4):
            if F2 - b_up[0] > tol:
                optimality = 0
                i1 = i_up[0]
        if optimality == 1:
            return 0
    
        if memb_i2 == 0:
            if b_low[0] - F2 > F2 - b_up[0]:
                i1 = i_low[0]
            else:
                i1 = i_up[0]
            
        if takeStep(i1,i2):
            return 1
        else:
            return 0
    
    ##############################################################################################
    
    
    
    
    ##############################################################################################
    #main routine
    
    numChanged = 0
    examineAll = 1

    while numChanged > 0 or examineAll:
        numChanged = 0
        if examineAll:
            for i in range(l):
                numChanged = numChanged + examineExample(i)
        else:
            for i in (np.nonzero(I[0,:]))[0]:
                numChanged = numChanged + examineExample(i)
                if b_up[0] > b_low[0] - tol:
                    numChanged = 0
                    break
        if examineAll == 1:
            examineAll = 0
        elif numChanged == 0:
            examineAll = 1
            
            
    if violationcheckyesorno == 'yes':
        memb = [I_membership_no(alpha[i],label[i]) for i in range(l)]
        I_up = [memb[i] in (0,1,2) for i in range(l)]
        I_low = [memb[i] in (0,3,4) for i in range(l)]
        bs = [F(i,alpha) for i in range(l)]

        b_up = float('inf')
        b_low = -b_up
        for i in range(l):
            if I_up[i] == 1 and bs[i] < b_up:
                b_up = bs[i]
            if I_low[i] == 1 and bs[i] > b_low:
                b_low = bs[i]

        if b_low - tol <= b_up:
            violationstring = 'no tol-violation'
        else:
            violationstring = 'tol-violations!!'
    else:
        violationstring = 'no violation requested'

    
    return {'solution': alpha, 'violationcheck': violationstring}

    ##############################################################################################

# %%
def smo_new(data,label,C,kernel,tol,violationcheckyesorno):
    
    #sehr wichtig!
    null = 1e-16
    
    def I_up_low_membership(alpha_i,label_i):
        v = np.array([False,False])
        if (alpha_i < C-null and label_i == 1) or (alpha_i > null and label_i == -1):
            v[0] = True
        if (alpha_i < C-null and label_i == -1) or (alpha_i > null and label_i == 1):
            v[1] = True
        return v
        
        
    #data: images are rows of array, so the number of columns is 28**2 and the number of rows is the number of training data
    l = label.shape[0]
    alpha = np.zeros(l)
    
    I = np.zeros((2,l),dtype = bool)
                  
    #initialize I, now logical vector! I[0] = I_up, I[1] = I_low
    I[0] = label == 1
    I[1] = label == -1
    
        
    b_up = -1
    b_low = 1
    
    v = np.array(range(l))
    i_up_array = v[I[0]]
    i_low_array = v[I[1]]
    
    i_0 = i_up_array[0]
    j_0 = i_low_array[0]
    
    #hier stimmt fcache noch!!!!!!!!!!
    fcache = -label.astype(float)
    #print('fcache error: ', fcache - [F(i,alpha) for i in range(l)])
    
    iter = 0
    cycle = 0
    
    #kostenintensiv bei SMO mit maximal violating pairs ist das ständige Neuberechnen der kompletten Kernel-Matrix; solange also
    #initialisiere daher lxl - Nullmatrix (numpy macht sie sparse, das geht also) und speichere alle bisher berechneten kernel-Berechnung ab
    #die Idee ist, dass das funktionieren sollte, da die meisten alpha_i auf Null bleiben; also sollte auch unsere Gram-Matrix
    #sparse bleiben
    
    #sparse, i.e., no memory overflow so far
    K = np.zeros([l,l])
    
    rows_calc = []
    
    while(b_up < b_low - tol):

        alph1 = alpha[i_0]
        alph2 = alpha[j_0]
        
        y1 = label[i_0]
        y2 = label[j_0]
        
        F1 = fcache[i_0]
        F2 = fcache[j_0]
        
        s = y1*y2
                
        if s == -1:
            L = max(0,alph2-alph1)
            H = min(C,C+alph2-alph1)
        else:
            L = max(0,alph2+alph1-C)
            H = min(C,alph2+alph1)
        
        if i_0 not in rows_calc:
            K[i_0] = [kernel(data[i],data[i_0]) for i in range(l)]
            rows_calc.append(i_0)
        
        if j_0 not in rows_calc:
            K[j_0] = [kernel(data[i],data[j_0]) for i in range(l)]
            rows_calc.append(j_0)
            
        #print(K)
            
        k11 = K[i_0,i_0]
        k12 = K[i_0,j_0]
        k22 = K[j_0,j_0]
        
        eta = 2*k12 - k11 - k22
        
        if eta < 0:
            a2 = alph2 - y2*(F1-F2)/eta
            if a2 < L:
                a2 = L
            elif a2 > H:
                a2 = H
        else:
            #print('Error: eta == 0')
            raise ValueError('Error: eta == 0')
        
        a1 = alph1 + s*(alph2-a2)
        
        #zum Vergleich, siehe unten, wo untersucht wird, wie oft es vorkommt, dass
        #ein Paar nach einem Schritt sofort wieder violating ist
        alpha_old = np.empty(alpha.shape)
        np.copyto(alpha_old, alpha) 
        
        # 3.) update alpha, I_up, I_low and then fcache
        alpha[i_0] = a1
        alpha[j_0] = a2
        
                 
        I[:,i_0] = I_up_low_membership(a1,y1)
        I[:,j_0] = I_up_low_membership(a2,y2)
        
        #prüfe, ob I richtig geupdatet wurde: erfolgreich, I wird korrekt geupdatet

        #w = list(v)
        #w.remove(i_0)
        #w.remove(j_0)
        #print('alpha außerhalb von i_0,j_0 gleich wenn Null:',np.linalg.norm((alpha_old-alpha)[w]))  
        
        #fac_i_0 = y1 * (a1 - alph1)
        #fac_j_0 = y2 * (a2 - alph2)
        
        #fcache += fac_i_0 * K[i_0]  + fac_j_0 * K[j_0]
        
        
        #behelfsmäßig
        #fcache = np.array([F(i,alpha) for i in range(l)])
        #print('fcache error: ', fcache2 - fcache)
        
        # 4.) berechne neues i_0 und j_0  für maximally violating pair und dazu b_up, b_low
        
        
        #now choose i_0,j_0 for next iteration and compute b_up, b_low for these i_0,j_0
     
                
        #Alternative:
        
        I_up = I[0]
        I_low = I[1]
        
        i_0_old = i_0
        j_0_old = j_0
        b_up = float('inf')
        b_low = -b_up
        
        iupset = []
        ilowset = []
        for i in range(l):
            if I_up[i] == 1 and fcache[i] < b_up:
                iupset.append(i)
                b_up = fcache[i]
                i_0 = i
            if I_low[i] == 1 and fcache[i] > b_low:
                ilowset.append(i)
                b_low = fcache[i]
                j_0 = i
                
        #if i_0 == i_0_old:
            #i_0 = np.random.choice(iupset)
        #if j_0 == j_0_old:
            #j_0 = np.random.choice(ilowset)
        
        
        
        
        
        
        if (1):
            #print('alpha =', alpha)
            #print('b_up =', b_up)
            #print('b_low =', b_low)
            #print('b_up - b_low =', b_up - b_low)
            if i_0_old == i_0 and j_0_old == j_0:
                cycle += 1
                print('Achtung, Paar zweimal hintereinander violating:')
                print('i_0 =',i_0,'j_0 =',j_0)
                print('alpha[i_0] =',alpha[i_0], 'alpha[j_0] =',alpha[j_0])
                print('alpha[i_0]_old =',alph1, 'alpha[j_0]_old =',alph2)
                print('fcache[i_0] =',fcache[i_0], 'fcache[j_0] =', fcache[j_0])
                print('fcache[i_0]_old =',F(i_0,alpha_old), 'fcache[j_0]_old =', F(j_0,alpha_old))
                print('b_up - b_low =', b_up - b_low)
            #print('min(fcache[I[0]]) =', np.min(fcache[I[0]]))
            #print('max(fcache[I[1]]) =', np.max(fcache[I[1]]))
                  
            #print('alpha * label =', np.dot(alpha,label))
            #print('i_0 =', i_0 )
            #print('j_0 =', j_0)
            #print('min(alpha) =', np.min(alpha))
            #print('max(alpha) =', np.max(alpha))
           
            #print('fcache error2: ', fcache2 - [F(i,alpha) for i in range(l)])
            
        iter += 1
        
        
    if violationcheckyesorno == 'yes':
        
        I_up = I[0]
        I_low = I[1]
        #bs = fcache
        bs = np.array([F(i,alpha) for i in range(l)])

        b_up = float('inf')
        b_low = -b_up
        for i in range(l):
            if I_up[i] == 1 and bs[i] < b_up:
                b_up = bs[i]
            if I_low[i] == 1 and bs[i] > b_low:
                b_low = bs[i]

        if b_low - tol <= b_up:
            violationstring = 'no tol-violation'
        else:
            violationstring = 'tol-violations!!'
    else:
        violationstring = 'no violation requested'    
   
    print('Anzahl wiederholt dasselbe Paar =', cycle)
    print('iter =', iter)
    return {'solution': alpha, 'violationcheck': violationstring}, b_up, b_low

# %%
def kernel(v1,v2):
    """standard scalar product"""
    return np.dot(v1,v2)

kernel_identifier = kernel.__doc__

# %%
# %%time
result = smo_new(data,label,1,kernel,1e-3,'yes')
print(result)
# Out:
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 1.44431445614e-05 alpha[j_0] = 1.44431445614e-05
# alpha[i_0]_old = 0.0 alpha[j_0]_old = 0.0
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = -1.0 fcache[j_0]_old = 1.0
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 2.88862891229e-05 alpha[j_0] = 2.88862891229e-05
# alpha[i_0]_old = 1.44431445614e-05 alpha[j_0]_old = 1.44431445614e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 0.555165590652 fcache[j_0]_old = 2.44994728252
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 4.33294336843e-05 alpha[j_0] = 4.33294336843e-05
# alpha[i_0]_old = 2.88862891229e-05 alpha[j_0]_old = 2.88862891229e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2.1103311813 fcache[j_0]_old = 3.89989456504
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 5.77725782457e-05 alpha[j_0] = 5.77725782457e-05
# alpha[i_0]_old = 4.33294336843e-05 alpha[j_0]_old = 4.33294336843e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 3.66549677196 fcache[j_0]_old = 5.34984184757
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 7.22157228072e-05 alpha[j_0] = 7.22157228072e-05
# alpha[i_0]_old = 5.77725782457e-05 alpha[j_0]_old = 5.77725782457e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 5.22066236261 fcache[j_0]_old = 6.79978913009
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 8.66588673686e-05 alpha[j_0] = 8.66588673686e-05
# alpha[i_0]_old = 7.22157228072e-05 alpha[j_0]_old = 7.22157228072e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 6.77582795326 fcache[j_0]_old = 8.24973641261
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00010110201193 alpha[j_0] = 0.00010110201193
# alpha[i_0]_old = 8.66588673686e-05 alpha[j_0]_old = 8.66588673686e-05
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 8.33099354391 fcache[j_0]_old = 9.69968369513
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000115545156491 alpha[j_0] = 0.000115545156491
# alpha[i_0]_old = 0.00010110201193 alpha[j_0]_old = 0.00010110201193
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 9.88615913457 fcache[j_0]_old = 11.1496309777
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000129988301053 alpha[j_0] = 0.000129988301053
# alpha[i_0]_old = 0.000115545156491 alpha[j_0]_old = 0.000115545156491
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 11.4413247252 fcache[j_0]_old = 12.5995782602
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000144431445614 alpha[j_0] = 0.000144431445614
# alpha[i_0]_old = 0.000129988301053 alpha[j_0]_old = 0.000129988301053
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 12.9964903159 fcache[j_0]_old = 14.0495255427
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000158874590176 alpha[j_0] = 0.000158874590176
# alpha[i_0]_old = 0.000144431445614 alpha[j_0]_old = 0.000144431445614
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 14.5516559065 fcache[j_0]_old = 15.4994728252
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000173317734737 alpha[j_0] = 0.000173317734737
# alpha[i_0]_old = 0.000158874590176 alpha[j_0]_old = 0.000158874590176
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 16.1068214972 fcache[j_0]_old = 16.9494201077
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000187760879299 alpha[j_0] = 0.000187760879299
# alpha[i_0]_old = 0.000173317734737 alpha[j_0]_old = 0.000173317734737
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 17.6619870878 fcache[j_0]_old = 18.3993673903
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00020220402386 alpha[j_0] = 0.00020220402386
# alpha[i_0]_old = 0.000187760879299 alpha[j_0]_old = 0.000187760879299
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 19.2171526785 fcache[j_0]_old = 19.8493146728
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000216647168422 alpha[j_0] = 0.000216647168422
# alpha[i_0]_old = 0.00020220402386 alpha[j_0]_old = 0.00020220402386
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 20.7723182691 fcache[j_0]_old = 21.2992619553
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000231090312983 alpha[j_0] = 0.000231090312983
# alpha[i_0]_old = 0.000216647168422 alpha[j_0]_old = 0.000216647168422
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 22.3274838598 fcache[j_0]_old = 22.7492092378
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000245533457544 alpha[j_0] = 0.000245533457544
# alpha[i_0]_old = 0.000231090312983 alpha[j_0]_old = 0.000231090312983
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 23.8826494504 fcache[j_0]_old = 24.1991565204
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000259976602106 alpha[j_0] = 0.000259976602106
# alpha[i_0]_old = 0.000245533457544 alpha[j_0]_old = 0.000245533457544
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 25.4378150411 fcache[j_0]_old = 25.6491038029
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000274419746667 alpha[j_0] = 0.000274419746667
# alpha[i_0]_old = 0.000259976602106 alpha[j_0]_old = 0.000259976602106
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 26.9929806317 fcache[j_0]_old = 27.0990510854
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000288862891229 alpha[j_0] = 0.000288862891229
# alpha[i_0]_old = 0.000274419746667 alpha[j_0]_old = 0.000274419746667
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 28.5481462224 fcache[j_0]_old = 28.5489983679
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00030330603579 alpha[j_0] = 0.00030330603579
# alpha[i_0]_old = 0.000288862891229 alpha[j_0]_old = 0.000288862891229
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 30.103311813 fcache[j_0]_old = 29.9989456504
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000317749180352 alpha[j_0] = 0.000317749180352
# alpha[i_0]_old = 0.00030330603579 alpha[j_0]_old = 0.00030330603579
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 31.6584774037 fcache[j_0]_old = 31.448892933
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000332192324913 alpha[j_0] = 0.000332192324913
# alpha[i_0]_old = 0.000317749180352 alpha[j_0]_old = 0.000317749180352
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 33.2136429944 fcache[j_0]_old = 32.8988402155
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000346635469474 alpha[j_0] = 0.000346635469474
# alpha[i_0]_old = 0.000332192324913 alpha[j_0]_old = 0.000332192324913
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 34.768808585 fcache[j_0]_old = 34.348787498
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000361078614036 alpha[j_0] = 0.000361078614036
# alpha[i_0]_old = 0.000346635469474 alpha[j_0]_old = 0.000346635469474
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 36.3239741757 fcache[j_0]_old = 35.7987347805
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000375521758597 alpha[j_0] = 0.000375521758597
# alpha[i_0]_old = 0.000361078614036 alpha[j_0]_old = 0.000361078614036
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 37.8791397663 fcache[j_0]_old = 37.2486820631
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000389964903159 alpha[j_0] = 0.000389964903159
# alpha[i_0]_old = 0.000375521758597 alpha[j_0]_old = 0.000375521758597
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 39.434305357 fcache[j_0]_old = 38.6986293456
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00040440804772 alpha[j_0] = 0.00040440804772
# alpha[i_0]_old = 0.000389964903159 alpha[j_0]_old = 0.000389964903159
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 40.9894709476 fcache[j_0]_old = 40.1485766281
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000418851192282 alpha[j_0] = 0.000418851192282
# alpha[i_0]_old = 0.00040440804772 alpha[j_0]_old = 0.00040440804772
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 42.5446365383 fcache[j_0]_old = 41.5985239106
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000433294336843 alpha[j_0] = 0.000433294336843
# alpha[i_0]_old = 0.000418851192282 alpha[j_0]_old = 0.000418851192282
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 44.0998021289 fcache[j_0]_old = 43.0484711931
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000447737481404 alpha[j_0] = 0.000447737481404
# alpha[i_0]_old = 0.000433294336843 alpha[j_0]_old = 0.000433294336843
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 45.6549677196 fcache[j_0]_old = 44.4984184757
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000462180625966 alpha[j_0] = 0.000462180625966
# alpha[i_0]_old = 0.000447737481404 alpha[j_0]_old = 0.000447737481404
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 47.2101333102 fcache[j_0]_old = 45.9483657582
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000476623770527 alpha[j_0] = 0.000476623770527
# alpha[i_0]_old = 0.000462180625966 alpha[j_0]_old = 0.000462180625966
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 48.7652989009 fcache[j_0]_old = 47.3983130407
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000491066915089 alpha[j_0] = 0.000491066915089
# alpha[i_0]_old = 0.000476623770527 alpha[j_0]_old = 0.000476623770527
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 50.3204644915 fcache[j_0]_old = 48.8482603232
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00050551005965 alpha[j_0] = 0.00050551005965
# alpha[i_0]_old = 0.000491066915089 alpha[j_0]_old = 0.000491066915089
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 51.8756300822 fcache[j_0]_old = 50.2982076058
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000519953204212 alpha[j_0] = 0.000519953204212
# alpha[i_0]_old = 0.00050551005965 alpha[j_0]_old = 0.00050551005965
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 53.4307956728 fcache[j_0]_old = 51.7481548883
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000534396348773 alpha[j_0] = 0.000534396348773
# alpha[i_0]_old = 0.000519953204212 alpha[j_0]_old = 0.000519953204212
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 54.9859612635 fcache[j_0]_old = 53.1981021708
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000548839493334 alpha[j_0] = 0.000548839493334
# alpha[i_0]_old = 0.000534396348773 alpha[j_0]_old = 0.000534396348773
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 56.5411268541 fcache[j_0]_old = 54.6480494533
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000563282637896 alpha[j_0] = 0.000563282637896
# alpha[i_0]_old = 0.000548839493334 alpha[j_0]_old = 0.000548839493334
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 58.0962924448 fcache[j_0]_old = 56.0979967358
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000577725782457 alpha[j_0] = 0.000577725782457
# alpha[i_0]_old = 0.000563282637896 alpha[j_0]_old = 0.000563282637896
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 59.6514580354 fcache[j_0]_old = 57.5479440184
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000592168927019 alpha[j_0] = 0.000592168927019
# alpha[i_0]_old = 0.000577725782457 alpha[j_0]_old = 0.000577725782457
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 61.2066236261 fcache[j_0]_old = 58.9978913009
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00060661207158 alpha[j_0] = 0.00060661207158
# alpha[i_0]_old = 0.000592168927019 alpha[j_0]_old = 0.000592168927019
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 62.7617892167 fcache[j_0]_old = 60.4478385834
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000621055216142 alpha[j_0] = 0.000621055216142
# alpha[i_0]_old = 0.00060661207158 alpha[j_0]_old = 0.00060661207158
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 64.3169548074 fcache[j_0]_old = 61.8977858659
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000635498360703 alpha[j_0] = 0.000635498360703
# alpha[i_0]_old = 0.000621055216142 alpha[j_0]_old = 0.000621055216142
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 65.8721203981 fcache[j_0]_old = 63.3477331485
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000649941505265 alpha[j_0] = 0.000649941505265
# alpha[i_0]_old = 0.000635498360703 alpha[j_0]_old = 0.000635498360703
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 67.4272859887 fcache[j_0]_old = 64.797680431
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000664384649826 alpha[j_0] = 0.000664384649826
# alpha[i_0]_old = 0.000649941505265 alpha[j_0]_old = 0.000649941505265
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 68.9824515794 fcache[j_0]_old = 66.2476277135
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000678827794387 alpha[j_0] = 0.000678827794387
# alpha[i_0]_old = 0.000664384649826 alpha[j_0]_old = 0.000664384649826
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 70.53761717 fcache[j_0]_old = 67.697574996
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000693270938949 alpha[j_0] = 0.000693270938949
# alpha[i_0]_old = 0.000678827794387 alpha[j_0]_old = 0.000678827794387
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 72.0927827607 fcache[j_0]_old = 69.1475222786
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00070771408351 alpha[j_0] = 0.00070771408351
# alpha[i_0]_old = 0.000693270938949 alpha[j_0]_old = 0.000693270938949
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 73.6479483513 fcache[j_0]_old = 70.5974695611
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000722157228072 alpha[j_0] = 0.000722157228072
# alpha[i_0]_old = 0.00070771408351 alpha[j_0]_old = 0.00070771408351
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 75.203113942 fcache[j_0]_old = 72.0474168436
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000736600372633 alpha[j_0] = 0.000736600372633
# alpha[i_0]_old = 0.000722157228072 alpha[j_0]_old = 0.000722157228072
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 76.7582795326 fcache[j_0]_old = 73.4973641261
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000751043517195 alpha[j_0] = 0.000751043517195
# alpha[i_0]_old = 0.000736600372633 alpha[j_0]_old = 0.000736600372633
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 78.3134451233 fcache[j_0]_old = 74.9473114086
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000765486661756 alpha[j_0] = 0.000765486661756
# alpha[i_0]_old = 0.000751043517195 alpha[j_0]_old = 0.000751043517195
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 79.8686107139 fcache[j_0]_old = 76.3972586912
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000779929806317 alpha[j_0] = 0.000779929806317
# alpha[i_0]_old = 0.000765486661756 alpha[j_0]_old = 0.000765486661756
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 81.4237763046 fcache[j_0]_old = 77.8472059737
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000794372950879 alpha[j_0] = 0.000794372950879
# alpha[i_0]_old = 0.000779929806317 alpha[j_0]_old = 0.000779929806317
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 82.9789418952 fcache[j_0]_old = 79.2971532562
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00080881609544 alpha[j_0] = 0.00080881609544
# alpha[i_0]_old = 0.000794372950879 alpha[j_0]_old = 0.000794372950879
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 84.5341074859 fcache[j_0]_old = 80.7471005387
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000823259240002 alpha[j_0] = 0.000823259240002
# alpha[i_0]_old = 0.00080881609544 alpha[j_0]_old = 0.00080881609544
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 86.0892730765 fcache[j_0]_old = 82.1970478213
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000837702384563 alpha[j_0] = 0.000837702384563
# alpha[i_0]_old = 0.000823259240002 alpha[j_0]_old = 0.000823259240002
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 87.6444386672 fcache[j_0]_old = 83.6469951038
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000852145529125 alpha[j_0] = 0.000852145529125
# alpha[i_0]_old = 0.000837702384563 alpha[j_0]_old = 0.000837702384563
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 89.1996042578 fcache[j_0]_old = 85.0969423863
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000866588673686 alpha[j_0] = 0.000866588673686
# alpha[i_0]_old = 0.000852145529125 alpha[j_0]_old = 0.000852145529125
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 90.7547698485 fcache[j_0]_old = 86.5468896688
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000881031818247 alpha[j_0] = 0.000881031818247
# alpha[i_0]_old = 0.000866588673686 alpha[j_0]_old = 0.000866588673686
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 92.3099354391 fcache[j_0]_old = 87.9968369513
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000895474962809 alpha[j_0] = 0.000895474962809
# alpha[i_0]_old = 0.000881031818247 alpha[j_0]_old = 0.000881031818247
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 93.8651010298 fcache[j_0]_old = 89.4467842339
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00090991810737 alpha[j_0] = 0.00090991810737
# alpha[i_0]_old = 0.000895474962809 alpha[j_0]_old = 0.000895474962809
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 95.4202666204 fcache[j_0]_old = 90.8967315164
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000924361251932 alpha[j_0] = 0.000924361251932
# alpha[i_0]_old = 0.00090991810737 alpha[j_0]_old = 0.00090991810737
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 96.9754322111 fcache[j_0]_old = 92.3466787989
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000938804396493 alpha[j_0] = 0.000938804396493
# alpha[i_0]_old = 0.000924361251932 alpha[j_0]_old = 0.000924361251932
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 98.5305978018 fcache[j_0]_old = 93.7966260814
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000953247541055 alpha[j_0] = 0.000953247541055
# alpha[i_0]_old = 0.000938804396493 alpha[j_0]_old = 0.000938804396493
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 100.085763392 fcache[j_0]_old = 95.246573364
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000967690685616 alpha[j_0] = 0.000967690685616
# alpha[i_0]_old = 0.000953247541055 alpha[j_0]_old = 0.000953247541055
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 101.640928983 fcache[j_0]_old = 96.6965206465
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000982133830178 alpha[j_0] = 0.000982133830178
# alpha[i_0]_old = 0.000967690685616 alpha[j_0]_old = 0.000967690685616
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 103.196094574 fcache[j_0]_old = 98.146467929
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.000996576974739 alpha[j_0] = 0.000996576974739
# alpha[i_0]_old = 0.000982133830178 alpha[j_0]_old = 0.000982133830178
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 104.751260164 fcache[j_0]_old = 99.5964152115
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0010110201193 alpha[j_0] = 0.0010110201193
# alpha[i_0]_old = 0.000996576974739 alpha[j_0]_old = 0.000996576974739
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 106.306425755 fcache[j_0]_old = 101.046362494
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00102546326386 alpha[j_0] = 0.00102546326386
# alpha[i_0]_old = 0.0010110201193 alpha[j_0]_old = 0.0010110201193
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 107.861591346 fcache[j_0]_old = 102.496309777
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00103990640842 alpha[j_0] = 0.00103990640842
# alpha[i_0]_old = 0.00102546326386 alpha[j_0]_old = 0.00102546326386
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 109.416756936 fcache[j_0]_old = 103.946257059
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00105434955298 alpha[j_0] = 0.00105434955298
# alpha[i_0]_old = 0.00103990640842 alpha[j_0]_old = 0.00103990640842
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 110.971922527 fcache[j_0]_old = 105.396204342
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00106879269755 alpha[j_0] = 0.00106879269755
# alpha[i_0]_old = 0.00105434955298 alpha[j_0]_old = 0.00105434955298
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 112.527088118 fcache[j_0]_old = 106.846151624
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00108323584211 alpha[j_0] = 0.00108323584211
# alpha[i_0]_old = 0.00106879269755 alpha[j_0]_old = 0.00106879269755
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 114.082253708 fcache[j_0]_old = 108.296098907
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00109767898667 alpha[j_0] = 0.00109767898667
# alpha[i_0]_old = 0.00108323584211 alpha[j_0]_old = 0.00108323584211
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 115.637419299 fcache[j_0]_old = 109.746046189
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00111212213123 alpha[j_0] = 0.00111212213123
# alpha[i_0]_old = 0.00109767898667 alpha[j_0]_old = 0.00109767898667
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 117.19258489 fcache[j_0]_old = 111.195993472
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00112656527579 alpha[j_0] = 0.00112656527579
# alpha[i_0]_old = 0.00111212213123 alpha[j_0]_old = 0.00111212213123
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 118.74775048 fcache[j_0]_old = 112.645940754
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00114100842035 alpha[j_0] = 0.00114100842035
# alpha[i_0]_old = 0.00112656527579 alpha[j_0]_old = 0.00112656527579
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 120.302916071 fcache[j_0]_old = 114.095888037
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00115545156491 alpha[j_0] = 0.00115545156491
# alpha[i_0]_old = 0.00114100842035 alpha[j_0]_old = 0.00114100842035
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 121.858081662 fcache[j_0]_old = 115.545835319
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00116989470948 alpha[j_0] = 0.00116989470948
# alpha[i_0]_old = 0.00115545156491 alpha[j_0]_old = 0.00115545156491
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 123.413247252 fcache[j_0]_old = 116.995782602
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00118433785404 alpha[j_0] = 0.00118433785404
# alpha[i_0]_old = 0.00116989470948 alpha[j_0]_old = 0.00116989470948
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 124.968412843 fcache[j_0]_old = 118.445729884
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0011987809986 alpha[j_0] = 0.0011987809986
# alpha[i_0]_old = 0.00118433785404 alpha[j_0]_old = 0.00118433785404
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 126.523578433 fcache[j_0]_old = 119.895677167
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00121322414316 alpha[j_0] = 0.00121322414316
# alpha[i_0]_old = 0.0011987809986 alpha[j_0]_old = 0.0011987809986
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 128.078744024 fcache[j_0]_old = 121.345624449
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00122766728772 alpha[j_0] = 0.00122766728772
# alpha[i_0]_old = 0.00121322414316 alpha[j_0]_old = 0.00121322414316
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 129.633909615 fcache[j_0]_old = 122.795571732
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00124211043228 alpha[j_0] = 0.00124211043228
# alpha[i_0]_old = 0.00122766728772 alpha[j_0]_old = 0.00122766728772
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 131.189075205 fcache[j_0]_old = 124.245519014
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00125655357684 alpha[j_0] = 0.00125655357684
# alpha[i_0]_old = 0.00124211043228 alpha[j_0]_old = 0.00124211043228
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 132.744240796 fcache[j_0]_old = 125.695466297
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00127099672141 alpha[j_0] = 0.00127099672141
# alpha[i_0]_old = 0.00125655357684 alpha[j_0]_old = 0.00125655357684
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 134.299406387 fcache[j_0]_old = 127.145413579
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00128543986597 alpha[j_0] = 0.00128543986597
# alpha[i_0]_old = 0.00127099672141 alpha[j_0]_old = 0.00127099672141
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 135.854571977 fcache[j_0]_old = 128.595360862
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00129988301053 alpha[j_0] = 0.00129988301053
# alpha[i_0]_old = 0.00128543986597 alpha[j_0]_old = 0.00128543986597
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 137.409737568 fcache[j_0]_old = 130.045308144
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00131432615509 alpha[j_0] = 0.00131432615509
# alpha[i_0]_old = 0.00129988301053 alpha[j_0]_old = 0.00129988301053
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 138.964903159 fcache[j_0]_old = 131.495255427
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00132876929965 alpha[j_0] = 0.00132876929965
# alpha[i_0]_old = 0.00131432615509 alpha[j_0]_old = 0.00131432615509
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 140.520068749 fcache[j_0]_old = 132.94520271
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00134321244421 alpha[j_0] = 0.00134321244421
# alpha[i_0]_old = 0.00132876929965 alpha[j_0]_old = 0.00132876929965
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 142.07523434 fcache[j_0]_old = 134.395149992
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00135765558877 alpha[j_0] = 0.00135765558877
# alpha[i_0]_old = 0.00134321244421 alpha[j_0]_old = 0.00134321244421
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 143.630399931 fcache[j_0]_old = 135.845097275
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00137209873334 alpha[j_0] = 0.00137209873334
# alpha[i_0]_old = 0.00135765558877 alpha[j_0]_old = 0.00135765558877
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 145.185565521 fcache[j_0]_old = 137.295044557
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0013865418779 alpha[j_0] = 0.0013865418779
# alpha[i_0]_old = 0.00137209873334 alpha[j_0]_old = 0.00137209873334
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 146.740731112 fcache[j_0]_old = 138.74499184
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00140098502246 alpha[j_0] = 0.00140098502246
# alpha[i_0]_old = 0.0013865418779 alpha[j_0]_old = 0.0013865418779
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 148.295896703 fcache[j_0]_old = 140.194939122
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00141542816702 alpha[j_0] = 0.00141542816702
# alpha[i_0]_old = 0.00140098502246 alpha[j_0]_old = 0.00140098502246
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 149.851062293 fcache[j_0]_old = 141.644886405
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00142987131158 alpha[j_0] = 0.00142987131158
# alpha[i_0]_old = 0.00141542816702 alpha[j_0]_old = 0.00141542816702
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 151.406227884 fcache[j_0]_old = 143.094833687
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00144431445614 alpha[j_0] = 0.00144431445614
# alpha[i_0]_old = 0.00142987131158 alpha[j_0]_old = 0.00142987131158
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 152.961393475 fcache[j_0]_old = 144.54478097
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0014587576007 alpha[j_0] = 0.0014587576007
# alpha[i_0]_old = 0.00144431445614 alpha[j_0]_old = 0.00144431445614
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 154.516559065 fcache[j_0]_old = 145.994728252
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00147320074527 alpha[j_0] = 0.00147320074527
# alpha[i_0]_old = 0.0014587576007 alpha[j_0]_old = 0.0014587576007
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 156.071724656 fcache[j_0]_old = 147.444675535
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00148764388983 alpha[j_0] = 0.00148764388983
# alpha[i_0]_old = 0.00147320074527 alpha[j_0]_old = 0.00147320074527
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 157.626890247 fcache[j_0]_old = 148.894622817
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00150208703439 alpha[j_0] = 0.00150208703439
# alpha[i_0]_old = 0.00148764388983 alpha[j_0]_old = 0.00148764388983
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 159.182055837 fcache[j_0]_old = 150.3445701
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00151653017895 alpha[j_0] = 0.00151653017895
# alpha[i_0]_old = 0.00150208703439 alpha[j_0]_old = 0.00150208703439
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 160.737221428 fcache[j_0]_old = 151.794517382
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00153097332351 alpha[j_0] = 0.00153097332351
# alpha[i_0]_old = 0.00151653017895 alpha[j_0]_old = 0.00151653017895
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 162.292387019 fcache[j_0]_old = 153.244464665
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00154541646807 alpha[j_0] = 0.00154541646807
# alpha[i_0]_old = 0.00153097332351 alpha[j_0]_old = 0.00153097332351
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 163.847552609 fcache[j_0]_old = 154.694411947
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00155985961263 alpha[j_0] = 0.00155985961263
# alpha[i_0]_old = 0.00154541646807 alpha[j_0]_old = 0.00154541646807
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 165.4027182 fcache[j_0]_old = 156.14435923
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0015743027572 alpha[j_0] = 0.0015743027572
# alpha[i_0]_old = 0.00155985961263 alpha[j_0]_old = 0.00155985961263
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 166.95788379 fcache[j_0]_old = 157.594306512
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00158874590176 alpha[j_0] = 0.00158874590176
# alpha[i_0]_old = 0.0015743027572 alpha[j_0]_old = 0.0015743027572
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 168.513049381 fcache[j_0]_old = 159.044253795
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00160318904632 alpha[j_0] = 0.00160318904632
# alpha[i_0]_old = 0.00158874590176 alpha[j_0]_old = 0.00158874590176
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 170.068214972 fcache[j_0]_old = 160.494201077
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00161763219088 alpha[j_0] = 0.00161763219088
# alpha[i_0]_old = 0.00160318904632 alpha[j_0]_old = 0.00160318904632
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 171.623380562 fcache[j_0]_old = 161.94414836
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00163207533544 alpha[j_0] = 0.00163207533544
# alpha[i_0]_old = 0.00161763219088 alpha[j_0]_old = 0.00161763219088
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 173.178546153 fcache[j_0]_old = 163.394095643
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00164651848 alpha[j_0] = 0.00164651848
# alpha[i_0]_old = 0.00163207533544 alpha[j_0]_old = 0.00163207533544
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 174.733711744 fcache[j_0]_old = 164.844042925
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00166096162456 alpha[j_0] = 0.00166096162456
# alpha[i_0]_old = 0.00164651848 alpha[j_0]_old = 0.00164651848
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 176.288877334 fcache[j_0]_old = 166.293990208
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00167540476913 alpha[j_0] = 0.00167540476913
# alpha[i_0]_old = 0.00166096162456 alpha[j_0]_old = 0.00166096162456
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 177.844042925 fcache[j_0]_old = 167.74393749
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00168984791369 alpha[j_0] = 0.00168984791369
# alpha[i_0]_old = 0.00167540476913 alpha[j_0]_old = 0.00167540476913
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 179.399208516 fcache[j_0]_old = 169.193884773
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00170429105825 alpha[j_0] = 0.00170429105825
# alpha[i_0]_old = 0.00168984791369 alpha[j_0]_old = 0.00168984791369
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 180.954374106 fcache[j_0]_old = 170.643832055
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00171873420281 alpha[j_0] = 0.00171873420281
# alpha[i_0]_old = 0.00170429105825 alpha[j_0]_old = 0.00170429105825
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 182.509539697 fcache[j_0]_old = 172.093779338
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00173317734737 alpha[j_0] = 0.00173317734737
# alpha[i_0]_old = 0.00171873420281 alpha[j_0]_old = 0.00171873420281
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 184.064705288 fcache[j_0]_old = 173.54372662
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00174762049193 alpha[j_0] = 0.00174762049193
# alpha[i_0]_old = 0.00173317734737 alpha[j_0]_old = 0.00173317734737
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 185.619870878 fcache[j_0]_old = 174.993673903
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00176206363649 alpha[j_0] = 0.00176206363649
# alpha[i_0]_old = 0.00174762049193 alpha[j_0]_old = 0.00174762049193
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 187.175036469 fcache[j_0]_old = 176.443621185
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00177650678106 alpha[j_0] = 0.00177650678106
# alpha[i_0]_old = 0.00176206363649 alpha[j_0]_old = 0.00176206363649
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 188.73020206 fcache[j_0]_old = 177.893568468
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00179094992562 alpha[j_0] = 0.00179094992562
# alpha[i_0]_old = 0.00177650678106 alpha[j_0]_old = 0.00177650678106
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 190.28536765 fcache[j_0]_old = 179.34351575
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00180539307018 alpha[j_0] = 0.00180539307018
# alpha[i_0]_old = 0.00179094992562 alpha[j_0]_old = 0.00179094992562
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 191.840533241 fcache[j_0]_old = 180.793463033
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00181983621474 alpha[j_0] = 0.00181983621474
# alpha[i_0]_old = 0.00180539307018 alpha[j_0]_old = 0.00180539307018
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 193.395698832 fcache[j_0]_old = 182.243410315
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0018342793593 alpha[j_0] = 0.0018342793593
# alpha[i_0]_old = 0.00181983621474 alpha[j_0]_old = 0.00181983621474
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 194.950864422 fcache[j_0]_old = 183.693357598
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00184872250386 alpha[j_0] = 0.00184872250386
# alpha[i_0]_old = 0.0018342793593 alpha[j_0]_old = 0.0018342793593
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 196.506030013 fcache[j_0]_old = 185.14330488
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00186316564842 alpha[j_0] = 0.00186316564842
# alpha[i_0]_old = 0.00184872250386 alpha[j_0]_old = 0.00184872250386
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 198.061195604 fcache[j_0]_old = 186.593252163
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00187760879299 alpha[j_0] = 0.00187760879299
# alpha[i_0]_old = 0.00186316564842 alpha[j_0]_old = 0.00186316564842
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 199.616361194 fcache[j_0]_old = 188.043199445
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00189205193755 alpha[j_0] = 0.00189205193755
# alpha[i_0]_old = 0.00187760879299 alpha[j_0]_old = 0.00187760879299
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 201.171526785 fcache[j_0]_old = 189.493146728
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00190649508211 alpha[j_0] = 0.00190649508211
# alpha[i_0]_old = 0.00189205193755 alpha[j_0]_old = 0.00189205193755
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 202.726692375 fcache[j_0]_old = 190.94309401
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00192093822667 alpha[j_0] = 0.00192093822667
# alpha[i_0]_old = 0.00190649508211 alpha[j_0]_old = 0.00190649508211
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 204.281857966 fcache[j_0]_old = 192.393041293
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00193538137123 alpha[j_0] = 0.00193538137123
# alpha[i_0]_old = 0.00192093822667 alpha[j_0]_old = 0.00192093822667
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 205.837023557 fcache[j_0]_old = 193.842988575
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00194982451579 alpha[j_0] = 0.00194982451579
# alpha[i_0]_old = 0.00193538137123 alpha[j_0]_old = 0.00193538137123
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 207.392189147 fcache[j_0]_old = 195.292935858
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00196426766036 alpha[j_0] = 0.00196426766036
# alpha[i_0]_old = 0.00194982451579 alpha[j_0]_old = 0.00194982451579
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 208.947354738 fcache[j_0]_old = 196.742883141
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00197871080492 alpha[j_0] = 0.00197871080492
# alpha[i_0]_old = 0.00196426766036 alpha[j_0]_old = 0.00196426766036
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 210.502520329 fcache[j_0]_old = 198.192830423
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00199315394948 alpha[j_0] = 0.00199315394948
# alpha[i_0]_old = 0.00197871080492 alpha[j_0]_old = 0.00197871080492
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 212.057685919 fcache[j_0]_old = 199.642777706
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00200759709404 alpha[j_0] = 0.00200759709404
# alpha[i_0]_old = 0.00199315394948 alpha[j_0]_old = 0.00199315394948
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 213.61285151 fcache[j_0]_old = 201.092724988
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0020220402386 alpha[j_0] = 0.0020220402386
# alpha[i_0]_old = 0.00200759709404 alpha[j_0]_old = 0.00200759709404
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 215.168017101 fcache[j_0]_old = 202.542672271
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00203648338316 alpha[j_0] = 0.00203648338316
# alpha[i_0]_old = 0.0020220402386 alpha[j_0]_old = 0.0020220402386
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 216.723182691 fcache[j_0]_old = 203.992619553
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00205092652772 alpha[j_0] = 0.00205092652772
# alpha[i_0]_old = 0.00203648338316 alpha[j_0]_old = 0.00203648338316
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 218.278348282 fcache[j_0]_old = 205.442566836
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00206536967229 alpha[j_0] = 0.00206536967229
# alpha[i_0]_old = 0.00205092652772 alpha[j_0]_old = 0.00205092652772
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 219.833513873 fcache[j_0]_old = 206.892514118
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00207981281685 alpha[j_0] = 0.00207981281685
# alpha[i_0]_old = 0.00206536967229 alpha[j_0]_old = 0.00206536967229
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 221.388679463 fcache[j_0]_old = 208.342461401
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00209425596141 alpha[j_0] = 0.00209425596141
# alpha[i_0]_old = 0.00207981281685 alpha[j_0]_old = 0.00207981281685
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 222.943845054 fcache[j_0]_old = 209.792408683
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00210869910597 alpha[j_0] = 0.00210869910597
# alpha[i_0]_old = 0.00209425596141 alpha[j_0]_old = 0.00209425596141
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 224.499010645 fcache[j_0]_old = 211.242355966
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00212314225053 alpha[j_0] = 0.00212314225053
# alpha[i_0]_old = 0.00210869910597 alpha[j_0]_old = 0.00210869910597
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 226.054176235 fcache[j_0]_old = 212.692303248
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00213758539509 alpha[j_0] = 0.00213758539509
# alpha[i_0]_old = 0.00212314225053 alpha[j_0]_old = 0.00212314225053
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 227.609341826 fcache[j_0]_old = 214.142250531
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00215202853965 alpha[j_0] = 0.00215202853965
# alpha[i_0]_old = 0.00213758539509 alpha[j_0]_old = 0.00213758539509
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 229.164507417 fcache[j_0]_old = 215.592197813
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00216647168422 alpha[j_0] = 0.00216647168422
# alpha[i_0]_old = 0.00215202853965 alpha[j_0]_old = 0.00215202853965
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 230.719673007 fcache[j_0]_old = 217.042145096
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00218091482878 alpha[j_0] = 0.00218091482878
# alpha[i_0]_old = 0.00216647168422 alpha[j_0]_old = 0.00216647168422
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 232.274838598 fcache[j_0]_old = 218.492092378
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.00219535797334 alpha[j_0] = 0.00219535797334
# alpha[i_0]_old = 0.00218091482878 alpha[j_0]_old = 0.00218091482878
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 233.830004189 fcache[j_0]_old = 219.942039661
# ...
# alpha[i_0]_old = 0.0211158773488 alpha[j_0]_old = 0.0211158773488
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2272.65209353 fcache[j_0]_old = 2120.82292705
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0211447636379 alpha[j_0] = 0.0211447636379
# alpha[i_0]_old = 0.0211303204934 alpha[j_0]_old = 0.0211303204934
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2274.20725912 fcache[j_0]_old = 2122.27287433
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0211592067825 alpha[j_0] = 0.0211592067825
# alpha[i_0]_old = 0.0211447636379 alpha[j_0]_old = 0.0211447636379
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2275.76242472 fcache[j_0]_old = 2123.72282161
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0211736499271 alpha[j_0] = 0.0211736499271
# alpha[i_0]_old = 0.0211592067825 alpha[j_0]_old = 0.0211592067825
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2277.31759031 fcache[j_0]_old = 2125.1727689
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0211880930716 alpha[j_0] = 0.0211880930716
# alpha[i_0]_old = 0.0211736499271 alpha[j_0]_old = 0.0211736499271
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2278.8727559 fcache[j_0]_old = 2126.62271618
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212025362162 alpha[j_0] = 0.0212025362162
# alpha[i_0]_old = 0.0211880930716 alpha[j_0]_old = 0.0211880930716
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2280.42792149 fcache[j_0]_old = 2128.07266346
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212169793607 alpha[j_0] = 0.0212169793607
# alpha[i_0]_old = 0.0212025362162 alpha[j_0]_old = 0.0212025362162
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2281.98308708 fcache[j_0]_old = 2129.52261074
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212314225053 alpha[j_0] = 0.0212314225053
# alpha[i_0]_old = 0.0212169793607 alpha[j_0]_old = 0.0212169793607
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2283.53825267 fcache[j_0]_old = 2130.97255803
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212458656499 alpha[j_0] = 0.0212458656499
# alpha[i_0]_old = 0.0212314225053 alpha[j_0]_old = 0.0212314225053
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2285.09341826 fcache[j_0]_old = 2132.42250531
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212603087944 alpha[j_0] = 0.0212603087944
# alpha[i_0]_old = 0.0212458656499 alpha[j_0]_old = 0.0212458656499
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2286.64858385 fcache[j_0]_old = 2133.87245259
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.021274751939 alpha[j_0] = 0.021274751939
# alpha[i_0]_old = 0.0212603087944 alpha[j_0]_old = 0.0212603087944
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2288.20374944 fcache[j_0]_old = 2135.32239987
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0212891950836 alpha[j_0] = 0.0212891950836
# alpha[i_0]_old = 0.021274751939 alpha[j_0]_old = 0.021274751939
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2289.75891503 fcache[j_0]_old = 2136.77234716
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213036382281 alpha[j_0] = 0.0213036382281
# alpha[i_0]_old = 0.0212891950836 alpha[j_0]_old = 0.0212891950836
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2291.31408062 fcache[j_0]_old = 2138.22229444
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213180813727 alpha[j_0] = 0.0213180813727
# alpha[i_0]_old = 0.0213036382281 alpha[j_0]_old = 0.0213036382281
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2292.86924621 fcache[j_0]_old = 2139.67224172
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213325245172 alpha[j_0] = 0.0213325245172
# alpha[i_0]_old = 0.0213180813727 alpha[j_0]_old = 0.0213180813727
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2294.4244118 fcache[j_0]_old = 2141.122189
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213469676618 alpha[j_0] = 0.0213469676618
# alpha[i_0]_old = 0.0213325245172 alpha[j_0]_old = 0.0213325245172
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2295.97957739 fcache[j_0]_old = 2142.57213629
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213614108064 alpha[j_0] = 0.0213614108064
# alpha[i_0]_old = 0.0213469676618 alpha[j_0]_old = 0.0213469676618
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2297.53474298 fcache[j_0]_old = 2144.02208357
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213758539509 alpha[j_0] = 0.0213758539509
# alpha[i_0]_old = 0.0213614108064 alpha[j_0]_old = 0.0213614108064
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2299.08990857 fcache[j_0]_old = 2145.47203085
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0213902970955 alpha[j_0] = 0.0213902970955
# alpha[i_0]_old = 0.0213758539509 alpha[j_0]_old = 0.0213758539509
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2300.64507417 fcache[j_0]_old = 2146.92197813
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.02140474024 alpha[j_0] = 0.02140474024
# alpha[i_0]_old = 0.0213902970955 alpha[j_0]_old = 0.0213902970955
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2302.20023976 fcache[j_0]_old = 2148.37192542
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214191833846 alpha[j_0] = 0.0214191833846
# alpha[i_0]_old = 0.02140474024 alpha[j_0]_old = 0.02140474024
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2303.75540535 fcache[j_0]_old = 2149.8218727
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214336265292 alpha[j_0] = 0.0214336265292
# alpha[i_0]_old = 0.0214191833846 alpha[j_0]_old = 0.0214191833846
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2305.31057094 fcache[j_0]_old = 2151.27181998
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214480696737 alpha[j_0] = 0.0214480696737
# alpha[i_0]_old = 0.0214336265292 alpha[j_0]_old = 0.0214336265292
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2306.86573653 fcache[j_0]_old = 2152.72176726
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214625128183 alpha[j_0] = 0.0214625128183
# alpha[i_0]_old = 0.0214480696737 alpha[j_0]_old = 0.0214480696737
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2308.42090212 fcache[j_0]_old = 2154.17171455
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214769559629 alpha[j_0] = 0.0214769559629
# alpha[i_0]_old = 0.0214625128183 alpha[j_0]_old = 0.0214625128183
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2309.97606771 fcache[j_0]_old = 2155.62166183
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0214913991074 alpha[j_0] = 0.0214913991074
# alpha[i_0]_old = 0.0214769559629 alpha[j_0]_old = 0.0214769559629
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2311.5312333 fcache[j_0]_old = 2157.07160911
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.021505842252 alpha[j_0] = 0.021505842252
# alpha[i_0]_old = 0.0214913991074 alpha[j_0]_old = 0.0214913991074
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2313.08639889 fcache[j_0]_old = 2158.52155639
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215202853965 alpha[j_0] = 0.0215202853965
# alpha[i_0]_old = 0.021505842252 alpha[j_0]_old = 0.021505842252
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2314.64156448 fcache[j_0]_old = 2159.97150368
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215347285411 alpha[j_0] = 0.0215347285411
# alpha[i_0]_old = 0.0215202853965 alpha[j_0]_old = 0.0215202853965
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2316.19673007 fcache[j_0]_old = 2161.42145096
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215491716857 alpha[j_0] = 0.0215491716857
# alpha[i_0]_old = 0.0215347285411 alpha[j_0]_old = 0.0215347285411
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2317.75189566 fcache[j_0]_old = 2162.87139824
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215636148302 alpha[j_0] = 0.0215636148302
# alpha[i_0]_old = 0.0215491716857 alpha[j_0]_old = 0.0215491716857
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2319.30706125 fcache[j_0]_old = 2164.32134552
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215780579748 alpha[j_0] = 0.0215780579748
# alpha[i_0]_old = 0.0215636148302 alpha[j_0]_old = 0.0215636148302
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2320.86222684 fcache[j_0]_old = 2165.77129281
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0215925011193 alpha[j_0] = 0.0215925011193
# alpha[i_0]_old = 0.0215780579748 alpha[j_0]_old = 0.0215780579748
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2322.41739243 fcache[j_0]_old = 2167.22124009
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216069442639 alpha[j_0] = 0.0216069442639
# alpha[i_0]_old = 0.0215925011193 alpha[j_0]_old = 0.0215925011193
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2323.97255803 fcache[j_0]_old = 2168.67118737
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216213874085 alpha[j_0] = 0.0216213874085
# alpha[i_0]_old = 0.0216069442639 alpha[j_0]_old = 0.0216069442639
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2325.52772362 fcache[j_0]_old = 2170.12113465
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.021635830553 alpha[j_0] = 0.021635830553
# alpha[i_0]_old = 0.0216213874085 alpha[j_0]_old = 0.0216213874085
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2327.08288921 fcache[j_0]_old = 2171.57108194
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216502736976 alpha[j_0] = 0.0216502736976
# alpha[i_0]_old = 0.021635830553 alpha[j_0]_old = 0.021635830553
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2328.6380548 fcache[j_0]_old = 2173.02102922
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216647168422 alpha[j_0] = 0.0216647168422
# alpha[i_0]_old = 0.0216502736976 alpha[j_0]_old = 0.0216502736976
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2330.19322039 fcache[j_0]_old = 2174.4709765
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216791599867 alpha[j_0] = 0.0216791599867
# alpha[i_0]_old = 0.0216647168422 alpha[j_0]_old = 0.0216647168422
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2331.74838598 fcache[j_0]_old = 2175.92092378
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0216936031313 alpha[j_0] = 0.0216936031313
# alpha[i_0]_old = 0.0216791599867 alpha[j_0]_old = 0.0216791599867
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2333.30355157 fcache[j_0]_old = 2177.37087107
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0217080462758 alpha[j_0] = 0.0217080462758
# alpha[i_0]_old = 0.0216936031313 alpha[j_0]_old = 0.0216936031313
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2334.85871716 fcache[j_0]_old = 2178.82081835
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0217224894204 alpha[j_0] = 0.0217224894204
# alpha[i_0]_old = 0.0217080462758 alpha[j_0]_old = 0.0217080462758
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2336.41388275 fcache[j_0]_old = 2180.27076563
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.021736932565 alpha[j_0] = 0.021736932565
# alpha[i_0]_old = 0.0217224894204 alpha[j_0]_old = 0.0217224894204
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2337.96904834 fcache[j_0]_old = 2181.72071291
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0217513757095 alpha[j_0] = 0.0217513757095
# alpha[i_0]_old = 0.021736932565 alpha[j_0]_old = 0.021736932565
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# fcache[i_0]_old = 2339.52421393 fcache[j_0]_old = 2183.1706602
# b_up - b_low = -2.0
# Achtung, Paar zweimal hintereinander violating:
# i_0 = 0 j_0 = 100
# alpha[i_0] = 0.0217658188541 alpha[j_0] = 0.0217658188541
# alpha[i_0]_old = 0.0217513757095 alpha[j_0]_old = 0.0217513757095
# fcache[i_0] = -1.0 fcache[j_0] = 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-67dc1940d160> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', "result = smo_new(data,label,1,kernel,1e-3,'yes')\nprint(result)")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-6-92560baf7420> in smo_new(data, label, C, kernel, tol, violationcheckyesorno)
#     179                 print('alpha[i_0]_old =',alph1, 'alpha[j_0]_old =',alph2)
#     180                 print('fcache[i_0] =',fcache[i_0], 'fcache[j_0] =', fcache[j_0])
# --> 181                 print('fcache[i_0]_old =',F(i_0,alpha_old), 'fcache[j_0]_old =', F(j_0,alpha_old))
#     182                 print('b_up - b_low =', b_up - b_low)
#     183             #print('min(fcache[I[0]]) =', np.min(fcache[I[0]]))
#
# <ipython-input-3-5f0482a540b7> in F(i, alpha)
#       3     out = - label[i]
#       4     for j in range(l):
# ----> 5         out += alpha[j]*label[j]*kernel(data[i],data[j])
#       6     return out
#
# <ipython-input-7-f2eb47b3213d> in kernel(v1, v2)
#       1 def kernel(v1,v2):
#       2     """standard scalar product"""
# ----> 3     return np.dot(v1,v2)
#       4
#       5 kernel_identifier = kernel.__doc__
#
# KeyboardInterrupt:

# %%
fcache = np.array([F(i,result[0]['solution']) for i in range(l)])

# %%
# %%time
result = smo_original(np.transpose(data),label,1,kernel,1e-3,'yes')
print(result)
